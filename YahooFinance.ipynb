# %%
import pandas as pd
import cointoss.sources.yahoofinance as yf

# %%
yf.get_info('AAPL')
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
yf.get_info('DAPP')
# Out:
# {'phone': '888-658-8287',
#  'longBusinessSummary': 'The fund normally invests at least 80% of its total assets in securities of Digital Transformation Companies. The index is a global index that tracks the performance of Digital Transformation Companies. The fund will not invest in digital assets (including cryptocurrencies) (i) directly or (ii) indirectly through the use of digital asset derivatives. It also will not invest in initial coin offerings. The fund is non-diversified.',
#  'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 20.69,
#  'open': 20.92,
#  'dayLow': 20.76,
#  'dayHigh': 21.68,
#  'regularMarketPreviousClose': 20.69,
#  'regularMarketOpen': 20.92,
#  'regularMarketDayLow': 20.76,
#  'regularMarketDayHigh': 21.68,
#  'trailingPE': 14.54725,
#  'volume': 670373,
#  'regularMarketVolume': 670373,
#  'averageVolume': 1037317,
#  'averageVolume10days': 1062820,
#  'averageDailyVolume10Day': 1062820,
# ...

# %%
yf.get_info('^GSPC')
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 7394.3,
#  'open': 7410.85,
#  'dayLow': 7363.01,
#  'dayHigh': 7456.4,
#  'regularMarketPreviousClose': 7394.3,
#  'regularMarketOpen': 7410.85,
#  'regularMarketDayLow': 7363.01,
#  'regularMarketDayHigh': 7456.4,
#  'volume': 2962242000,
#  'regularMarketVolume': 2962242000,
#  'averageVolume': 5459655396,
#  'averageVolume10days': 5599375000,
#  'averageDailyVolume10Day': 5599375000,
#  'bid': 7391.69,
#  'ask': 7460.89,
#  'bidSize': 0,
#  'askSize': 0,
#  'fiftyTwoWeekLow': 5943.23,
#  'fiftyTwoWeekHigh': 7620.9,
#  'allTimeHigh': 7620.9,
#  'allTimeLow': 4.4,
#  'fiftyDayAverage': 7247.7896,
#  'twoHundredDayAverage': 6881.9946,
#  'currency': 'USD',
#  'tradeable': False,
#  '52WeekChange': 23.177933,
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Index',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
# ...
